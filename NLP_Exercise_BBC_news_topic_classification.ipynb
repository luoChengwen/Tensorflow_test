# %% [markdown]
# <a href="https://colab.research.google.com/github/luoChengwen/Tensorflow_test/blob/master/NLP_Exercise_BBC_news_topic_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import tensorflow as tf
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# !wget --no-check-certificate \
    https://storage.googleapis.com/laurencemoroney-blog.appspot.com/bbc-text.csv \
    -O /tmp/bbc-text.csv
# Out:
# --2019-08-10 08:31:29--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/bbc-text.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.140.128, 2a00:1450:400c:c02::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.140.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5057493 (4.8M) [application/octet-stream]
# Saving to: ‘/tmp/bbc-text.csv’
#
# /tmp/bbc-text.csv   100%[===================>]   4.82M  --.-KB/s    in 0.03s
#
# 2019-08-10 08:31:29 (185 MB/s) - ‘/tmp/bbc-text.csv’ saved [5057493/5057493]

# %%
print(tf.__version__)
# Out:
# 2.0.0-beta1

# %%
vocab_size = 12000
embedding_dim = 20
max_length = 120
trunc_type = 'post'
padding_type = 'post'
oov_tok = 'OOV'
training_portion = .8

# %%
sentences = []
labels = []
stopwords = [ "a", "about", "above", "after", "again", "against", "all", "am", "an", "and", "any", "are", "as", "at", "be", "because", "been", "before", "being", "below", "between", "both", "but", "by", "could", "did", "do", "does", "doing", "down", "during", "each", "few", "for", "from", "further", "had", "has", "have", "having", "he", "he'd", "he'll", "he's", "her", "here", "here's", "hers", "herself", "him", "himself", "his", "how", "how's", "i", "i'd", "i'll", "i'm", "i've", "if", "in", "into", "is", "it", "it's", "its", "itself", "let's", "me", "more", "most", "my", "myself", "nor", "of", "on", "once", "only", "or", "other", "ought", "our", "ours", "ourselves", "out", "over", "own", "same", "she", "she'd", "she'll", "she's", "should", "so", "some", "such", "than", "that", "that's", "the", "their", "theirs", "them", "themselves", "then", "there", "there's", "these", "they", "they'd", "they'll", "they're", "they've", "this", "those", "through", "to", "too", "under", "until", "up", "very", "was", "we", "we'd", "we'll", "we're", "we've", "were", "what", "what's", "when", "when's", "where", "where's", "which", "while", "who", "who's", "whom", "why", "why's", "with", "would", "you", "you'd", "you'll", "you're", "you've", "your", "yours", "yourself", "yourselves" ]
print(len(stopwords))
# Expected Output
# 153
# Out:
# 153

# %%
import pandas as pd

data = pd.read_csv('/tmp/bbc-text.csv')

print(data.head())
# Out:
#         category                                               text
# 0           tech  tv future in the hands of viewers with home th...
# 1       business  worldcom boss  left books alone  former worldc...
# 2          sport  tigers wary of farrell  gamble  leicester say ...
# 3          sport  yeading face newcastle in fa cup premiership s...
# 4  entertainment  ocean s twelve raids box office ocean s twelve...

# %%
labels = np.array(data.loc[:,'category'])
sentences = data.loc[:,'text']
sent2 = []
for i in sentences:
  l = [m for m in i.split(' ') if (m not in stopwords) & (len(m)>0)]
  sent2.append(' '.join(l))
print(len(labels))
print(len(sent2))
print(sent2[0])
# # Expected Output
# # 2225
# # 2225
# # tv future hands viewers home theatre systems  plasma high-definition tvs  digital video recorders moving living room  way people watch tv will radically different five years  time.  according expert panel gathered annual consumer electronics show las vegas discuss new technologies will impact one favourite pastimes. us leading trend  programmes content will delivered viewers via home networks  cable  satellite  telecoms companies  broadband service providers front rooms portable devices.  one talked-about technologies ces digital personal video recorders (dvr pvr). set-top boxes  like us s tivo uk s sky+ system  allow people record  store  play  pause forward wind tv programmes want.  essentially  technology allows much personalised tv. also built-in high-definition tv sets  big business japan us  slower take off europe lack high-definition programming. not can people forward wind adverts  can also forget abiding network channel schedules  putting together a-la-carte entertainment. us networks cable satellite companies worried means terms advertising revenues well  brand identity  viewer loyalty channels. although us leads technology moment  also concern raised europe  particularly growing uptake services like sky+.  happens today  will see nine months years  time uk   adam hume  bbc broadcast s futurologist told bbc news website. likes bbc  no issues lost advertising revenue yet. pressing issue moment commercial uk broadcasters  brand loyalty important everyone.  will talking content brands rather network brands   said tim hanlon  brand communications firm starcom mediavest.  reality broadband connections  anybody can producer content.  added:  challenge now hard promote programme much choice.   means  said stacey jolna  senior vice president tv guide tv group  way people find content want watch simplified tv viewers. means networks  us terms  channels take leaf google s book search engine future  instead scheduler help people find want watch. kind channel model might work younger ipod generation used taking control gadgets play them. might not suit everyone  panel recognised. older generations comfortable familiar schedules channel brands know getting. perhaps not want much choice put hands  mr hanlon suggested.  end  kids just diapers pushing buttons already - everything possible available   said mr hanlon.  ultimately  consumer will tell market want.   50 000 new gadgets technologies showcased ces  many enhancing tv-watching experience. high-definition tv sets everywhere many new models lcd (liquid crystal display) tvs launched dvr capability built  instead external boxes. one example launched show humax s 26-inch lcd tv 80-hour tivo dvr dvd recorder. one us s biggest satellite tv companies  directtv  even launched branded dvr show 100-hours recording capability  instant replay  search function. set can pause rewind tv 90 hours. microsoft chief bill gates announced pre-show keynote speech partnership tivo  called tivotogo  means people can play recorded programmes windows pcs mobile devices. reflect increasing trend freeing multimedia people can watch want  want.
# Out:
# 2225
# 2225
# tv future hands viewers home theatre systems plasma high-definition tvs digital video recorders moving living room way people watch tv will radically different five years time. according expert panel gathered annual consumer electronics show las vegas discuss new technologies will impact one favourite pastimes. us leading trend programmes content will delivered viewers via home networks cable satellite telecoms companies broadband service providers front rooms portable devices. one talked-about technologies ces digital personal video recorders (dvr pvr). set-top boxes like us s tivo uk s sky+ system allow people record store play pause forward wind tv programmes want. essentially technology allows much personalised tv. also built-in high-definition tv sets big business japan us slower take off europe lack high-definition programming. not can people forward wind adverts can also forget abiding network channel schedules putting together a-la-carte entertainment. us networks cable satellite companies worried means terms advertising revenues well brand identity viewer loyalty channels. although us leads technology moment also concern raised europe particularly growing uptake services like sky+. happens today will see nine months years time uk adam hume bbc broadcast s futurologist told bbc news website. likes bbc no issues lost advertising revenue yet. pressing issue moment commercial uk broadcasters brand loyalty important everyone. will talking content brands rather network brands said tim hanlon brand communications firm starcom mediavest. reality broadband connections anybody can producer content. added: challenge now hard promote programme much choice. means said stacey jolna senior vice president tv guide tv group way people find content want watch simplified tv viewers. means networks us terms channels take leaf google s book search engine future instead scheduler help people find want watch. kind channel model might work younger ipod generation used taking control gadgets play them. might not suit everyone panel recognised. older generations comfortable familiar schedules channel brands know getting. perhaps not want much choice put hands mr hanlon suggested. end kids just diapers pushing buttons already - everything possible available said mr hanlon. ultimately consumer will tell market want. 50 000 new gadgets technologies showcased ces many enhancing tv-watching experience. high-definition tv sets everywhere many new models lcd (liquid crystal display) tvs launched dvr capability built instead external boxes. one example launched show humax s 26-inch lcd tv 80-hour tivo dvr dvd recorder. one us s biggest satellite tv companies directtv even launched branded dvr show 100-hours recording capability instant replay search function. set can pause rewind tv 90 hours. microsoft chief bill gates announced pre-show keynote speech partnership tivo called tivotogo means people can play recorded programmes windows pcs mobile devices. reflect increasing trend freeing multimedia people can watch want want.

# %%
train_size = int(len(sent2) * training_portion) # YOUR CODE HERE

# %%
train_sentences =  sent2[:train_size]# YOUR CODE HERE
train_labels = labels[:train_size] # YOUR CODE HERE

validation_sentences = sent2[train_size:] # YOUR CODE HERE
validation_labels = labels[train_size:]# YOUR CODE HERE

print(train_size)
print(len(train_sentences))
print(len(train_labels))
print(len(validation_sentences))
print(len(validation_labels))

# Expected output (if training_portion=.8)
# 1780
# 1780
# 1780
# 445
# 445
# Out:
# 1780
# 1780
# 1780
# 445
# 445

# %%
tokenizer = Tokenizer(num_words=max_length, oov_token = oov_tok)# YOUR CODE HERE
tokenizer.fit_on_texts(sent2)# YOUR CODE HERE
word_index = tokenizer.word_index # YOUR CODE HERE

train_sequences = tokenizer.texts_to_sequences(train_sentences)# YOUR CODE HERE
train_padded = pad_sequences(train_sequences, padding=padding_type, truncating = trunc_type, maxlen= max_length)# YOUR CODE HERE

print(len(train_sequences[0]))
print(len(train_padded[0]))

print(len(train_sequences[1]))
print(len(train_padded[1]))

print(len(train_sequences[10]))
print(len(train_padded[10]))

# Expected Ouput
# 449
# 120
# 200
# 120
# 192
# 120

print(len(train_padded))
# Out:
# 449
# 120
# 200
# 120
# 192
# 120
# 1780

# %%
validation_sequences = tokenizer.texts_to_sequences(validation_sentences)# YOUR CODE HERE
validation_padded = pad_sequences(validation_sequences, maxlen= max_length, padding = padding_type, truncating = trunc_type) # YOUR CODE HERE

print(len(validation_sequences))
print(validation_padded.shape)

# Expected output
# 445
# (445, 120)
# Out:
# 445
# (445, 120)

# %%
label_tokenizer = Tokenizer() # YOUR CODE HERE
label_tokenizer.fit_on_texts(labels)# YOUR CODE HERE

training_label_seq = np.array(label_tokenizer.texts_to_sequences(train_labels)) # YOUR CODE HERE
validation_label_seq = np.array(label_tokenizer.texts_to_sequences(validation_labels)) # YOUR CODE HERE

print(training_label_seq[0])
print(training_label_seq[1])
print(training_label_seq[2])
print(training_label_seq.shape)

print(validation_label_seq[0])
print(validation_label_seq[1])
print(validation_label_seq[2])
print(validation_label_seq.shape)

# Expected output
# [4]
# [2]
# [1]
# (1780, 1)
# [5]
# [4]
# [3]
# (445, 1)
# Out:
# [4]
# [2]
# [1]
# (1780, 1)
# [5]
# [4]
# [3]
# (445, 1)

# %%
model = tf.keras.Sequential([
# YOUR CODE HERE
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(24, activation='relu'),
    tf.keras.layers.Dense(6,activation='softmax')
    
])
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()

# Expected Output
# Layer (type)                 Output Shape              Param #   
# =================================================================
# embedding (Embedding)        (None, 120, 20)           16000     
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 20)                0         
# _________________________________________________________________
# dense (Dense)                (None, 24)                408       
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 150       
# =================================================================
# Total params: 16,558
# Trainable params: 16,558
# Non-trainable params: 0
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 120, 20)           240000
# _________________________________________________________________
# global_average_pooling1d_4 ( (None, 20)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 24)                504
# _________________________________________________________________
# dense_7 (Dense)              (None, 6)                 150
# =================================================================
# Total params: 240,654
# Trainable params: 240,654
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epochs = 30
history = model.fit(train_padded, training_label_seq, epochs= num_epochs, validation_data = (validation_padded, validation_label_seq))# YOUR CODE HERE
# Out:
# Train on 1780 samples, validate on 445 samples
# Epoch 1/30
# 1780/1780 [==============================] - 1s 413us/sample - loss: 1.7608 - accuracy: 0.2242 - val_loss: 1.7170 - val_accuracy: 0.2270
# Epoch 2/30
# 1780/1780 [==============================] - 0s 257us/sample - loss: 1.6886 - accuracy: 0.2303 - val_loss: 1.6469 - val_accuracy: 0.2270
# Epoch 3/30
# 1780/1780 [==============================] - 0s 259us/sample - loss: 1.6340 - accuracy: 0.2303 - val_loss: 1.6048 - val_accuracy: 0.2270
# Epoch 4/30
# 1780/1780 [==============================] - 0s 261us/sample - loss: 1.5972 - accuracy: 0.2399 - val_loss: 1.5745 - val_accuracy: 0.3865
# Epoch 5/30
# 1780/1780 [==============================] - 0s 267us/sample - loss: 1.5649 - accuracy: 0.3169 - val_loss: 1.5404 - val_accuracy: 0.4045
# Epoch 6/30
# 1780/1780 [==============================] - 0s 277us/sample - loss: 1.5224 - accuracy: 0.3831 - val_loss: 1.4884 - val_accuracy: 0.4539
# Epoch 7/30
# 1780/1780 [==============================] - 0s 262us/sample - loss: 1.4640 - accuracy: 0.4989 - val_loss: 1.4230 - val_accuracy: 0.5258
# Epoch 8/30
# 1780/1780 [==============================] - 0s 274us/sample - loss: 1.3864 - accuracy: 0.5421 - val_loss: 1.3402 - val_accuracy: 0.5663
# Epoch 9/30
# 1780/1780 [==============================] - 0s 258us/sample - loss: 1.2998 - accuracy: 0.6000 - val_loss: 1.2487 - val_accuracy: 0.5640
# Epoch 10/30
# 1780/1780 [==============================] - 0s 268us/sample - loss: 1.2078 - accuracy: 0.6107 - val_loss: 1.1633 - val_accuracy: 0.6067
# Epoch 11/30
# 1780/1780 [==============================] - 0s 264us/sample - loss: 1.1235 - accuracy: 0.6573 - val_loss: 1.0868 - val_accuracy: 0.6404
# Epoch 12/30
# 1780/1780 [==============================] - 0s 278us/sample - loss: 1.0450 - accuracy: 0.6697 - val_loss: 1.0159 - val_accuracy: 0.6697
# Epoch 13/30
# 1780/1780 [==============================] - 0s 262us/sample - loss: 0.9752 - accuracy: 0.7090 - val_loss: 0.9577 - val_accuracy: 0.7034
# Epoch 14/30
# 1780/1780 [==============================] - 0s 257us/sample - loss: 0.9116 - accuracy: 0.7264 - val_loss: 0.9049 - val_accuracy: 0.7169
# Epoch 15/30
# 1780/1780 [==============================] - 0s 269us/sample - loss: 0.8557 - accuracy: 0.7517 - val_loss: 0.8613 - val_accuracy: 0.7191
# Epoch 16/30
# 1780/1780 [==============================] - 0s 259us/sample - loss: 0.8070 - accuracy: 0.7551 - val_loss: 0.8309 - val_accuracy: 0.7281
# Epoch 17/30
# 1780/1780 [==============================] - 0s 267us/sample - loss: 0.7665 - accuracy: 0.7764 - val_loss: 0.7859 - val_accuracy: 0.7506
# Epoch 18/30
# 1780/1780 [==============================] - 0s 264us/sample - loss: 0.7270 - accuracy: 0.7798 - val_loss: 0.7572 - val_accuracy: 0.7596
# Epoch 19/30
# 1780/1780 [==============================] - 0s 271us/sample - loss: 0.6931 - accuracy: 0.7910 - val_loss: 0.7304 - val_accuracy: 0.7528
# Epoch 20/30
# 1780/1780 [==============================] - 0s 263us/sample - loss: 0.6670 - accuracy: 0.7938 - val_loss: 0.7105 - val_accuracy: 0.7730
# Epoch 21/30
# 1780/1780 [==============================] - 0s 264us/sample - loss: 0.6352 - accuracy: 0.8045 - val_loss: 0.6867 - val_accuracy: 0.7685
# Epoch 22/30
# 1780/1780 [==============================] - 1s 282us/sample - loss: 0.6082 - accuracy: 0.8129 - val_loss: 0.6693 - val_accuracy: 0.7528
# Epoch 23/30
# 1780/1780 [==============================] - 0s 264us/sample - loss: 0.5901 - accuracy: 0.8146 - val_loss: 0.6467 - val_accuracy: 0.7775
# Epoch 24/30
# 1780/1780 [==============================] - 0s 278us/sample - loss: 0.5671 - accuracy: 0.8202 - val_loss: 0.6329 - val_accuracy: 0.7753
# Epoch 25/30
# 1780/1780 [==============================] - 1s 284us/sample - loss: 0.5462 - accuracy: 0.8236 - val_loss: 0.6111 - val_accuracy: 0.7955
# Epoch 26/30
# 1780/1780 [==============================] - 0s 265us/sample - loss: 0.5259 - accuracy: 0.8303 - val_loss: 0.5968 - val_accuracy: 0.7910
# Epoch 27/30
# 1780/1780 [==============================] - 0s 280us/sample - loss: 0.5120 - accuracy: 0.8371 - val_loss: 0.5864 - val_accuracy: 0.7910
# Epoch 28/30
# 1780/1780 [==============================] - 0s 275us/sample - loss: 0.4982 - accuracy: 0.8354 - val_loss: 0.5750 - val_accuracy: 0.7933
# Epoch 29/30
# 1780/1780 [==============================] - 0s 276us/sample - loss: 0.4822 - accuracy: 0.8427 - val_loss: 0.5719 - val_accuracy: 0.8022
# Epoch 30/30
# 1780/1780 [==============================] - 0s 264us/sample - loss: 0.4681 - accuracy: 0.8461 - val_loss: 0.5547 - val_accuracy: 0.7933

# %%
import matplotlib.pyplot as plt


def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()
  
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %%
print(word_index.items())
# Out:
# dict_items([('OOV', 1), ('s', 2), ('said', 3), ('will', 4), ('not', 5), ('mr', 6), ('year', 7), ('also', 8), ('people', 9), ('new', 10), ('us', 11), ('one', 12), ('can', 13), ('last', 14), ('first', 15), ('t', 16), ('time', 17), ('two', 18), ('world', 19), ('government', 20), ('now', 21), ('uk', 22), ('years', 23), ('no', 24), ('best', 25), ('just', 26), ('make', 27), ('told', 28), ('get', 29), ('film', 30), ('like', 31), ('game', 32), ('made', 33), ('back', 34), ('music', 35), ('many', 36), ('three', 37), ('000', 38), ('labour', 39), ('next', 40), ('1', 41), ('bbc', 42), ('well', 43), ('set', 44), ('number', 45), ('take', 46), ('way', 47), ('added', 48), ('market', 49), ('2', 50), ('may', 51), ('says', 52), ('company', 53), ('home', 54), ('election', 55), ('off', 56), ('good', 57), ('2004', 58), ('going', 59), ('party', 60), ('still', 61), ('games', 62), ('much', 63), ('england', 64), ('win', 65), ('6', 66), ('go', 67), ('work', 68), ('since', 69), ('firm', 70), ('second', 71), ('show', 72), ('top', 73), ('blair', 74), ('won', 75), ('think', 76), ('week', 77), ('use', 78), ('say', 79), ('million', 80), ('part', 81), ('play', 82), ('technology', 83), ('minister', 84), ('high', 85), ('public', 86), ('want', 87), ('3', 88), ('mobile', 89), ('see', 90), ('british', 91), ('five', 92), ('10', 93), ('used', 94), ('country', 95), ('tv', 96), ('european', 97), ('players', 98), ('news', 99), ('end', 100), ('however', 101), ('expected', 102), ('4', 103), ('four', 104), ('group', 105), ('even', 106), ('sales', 107), ('5', 108), ('plans', 109), ('six', 110), ('old', 111), ('half', 112), ('already', 113), ('put', 114), ('brown', 115), ('growth', 116), ('months', 117), ('come', 118), ('day', 119), ('m', 120), ('london', 121), ('chief', 122), ('service', 123), ('net', 124), ('britain', 125), ('economy', 126), ('former', 127), ('don', 128), ('long', 129), ('2005', 130), ('money', 131), ('director', 132), ('tax', 133), ('deal', 134), ('companies', 135), ('services', 136), ('right', 137), ('record', 138), ('industry', 139), ('according', 140), ('help', 141), ('based', 142), ('need', 143), ('month', 144), ('system', 145), ('users', 146), ('digital', 147), ('big', 148), ('europe', 149), ('including', 150), ('international', 151), ('place', 152), ('team', 153), ('third', 154), ('around', 155), ('firms', 156), ('2003', 157), ('report', 158), ('business', 159), ('economic', 160), ('wales', 161), ('re', 162), ('called', 163), ('great', 164), ('really', 165), ('phone', 166), ('move', 167), ('software', 168), ('another', 169), ('open', 170), ('life', 171), ('bank', 172), ('final', 173), ('7', 174), ('got', 175), ('future', 176), ('hit', 177), ('start', 178), ('club', 179), ('took', 180), ('general', 181), ('up', 182), ('howard', 183), ('video', 184), ('know', 185), ('came', 186), ('france', 187), ('better', 188), ('spokesman', 189), ('information', 190), ('radio', 191), ('state', 192), ('office', 193), ('law', 194), ('online', 195), ('without', 196), ('court', 197), ('decision', 198), ('side', 199), ('real', 200), ('united', 201), ('ireland', 202), ('computer', 203), ('despite', 204), ('president', 205), ('found', 206), ('far', 207), ('making', 208), ('campaign', 209), ('action', 210), ('using', 211), ('likely', 212), ('prime', 213), ('data', 214), ('security', 215), ('seen', 216), ('figures', 217), ('china', 218), ('give', 219), ('media', 220), ('saying', 221), ('line', 222), ('ve', 223), ('lot', 224), ('given', 225), ('national', 226), ('run', 227), ('o', 228), ('awards', 229), ('away', 230), ('executive', 231), ('able', 232), ('offer', 233), ('countries', 234), ('foreign', 235), ('every', 236), ('january', 237), ('star', 238), ('it', 239), ('player', 240), ('internet', 241), ('oil', 242), ('lost', 243), ('times', 244), ('become', 245), ('december', 246), ('rise', 247), ('biggest', 248), ('match', 249), ('cup', 250), ('although', 251), ('left', 252), ('look', 253), ('anti', 254), ('man', 255), ('nations', 256), ('playing', 257), ('cost', 258), ('secr ...

# %%
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

def decode_sentence(text):
    return ' '.join([reverse_word_index.get(i, '?') for i in text])

# %%
print(reverse_word_index.items())
# Out:
# dict_items([(1, 'OOV'), (2, 's'), (3, 'said'), (4, 'will'), (5, 'not'), (6, 'mr'), (7, 'year'), (8, 'also'), (9, 'people'), (10, 'new'), (11, 'us'), (12, 'one'), (13, 'can'), (14, 'last'), (15, 'first'), (16, 't'), (17, 'time'), (18, 'two'), (19, 'world'), (20, 'government'), (21, 'now'), (22, 'uk'), (23, 'years'), (24, 'no'), (25, 'best'), (26, 'just'), (27, 'make'), (28, 'told'), (29, 'get'), (30, 'film'), (31, 'like'), (32, 'game'), (33, 'made'), (34, 'back'), (35, 'music'), (36, 'many'), (37, 'three'), (38, '000'), (39, 'labour'), (40, 'next'), (41, '1'), (42, 'bbc'), (43, 'well'), (44, 'set'), (45, 'number'), (46, 'take'), (47, 'way'), (48, 'added'), (49, 'market'), (50, '2'), (51, 'may'), (52, 'says'), (53, 'company'), (54, 'home'), (55, 'election'), (56, 'off'), (57, 'good'), (58, '2004'), (59, 'going'), (60, 'party'), (61, 'still'), (62, 'games'), (63, 'much'), (64, 'england'), (65, 'win'), (66, '6'), (67, 'go'), (68, 'work'), (69, 'since'), (70, 'firm'), (71, 'second'), (72, 'show'), (73, 'top'), (74, 'blair'), (75, 'won'), (76, 'think'), (77, 'week'), (78, 'use'), (79, 'say'), (80, 'million'), (81, 'part'), (82, 'play'), (83, 'technology'), (84, 'minister'), (85, 'high'), (86, 'public'), (87, 'want'), (88, '3'), (89, 'mobile'), (90, 'see'), (91, 'british'), (92, 'five'), (93, '10'), (94, 'used'), (95, 'country'), (96, 'tv'), (97, 'european'), (98, 'players'), (99, 'news'), (100, 'end'), (101, 'however'), (102, 'expected'), (103, '4'), (104, 'four'), (105, 'group'), (106, 'even'), (107, 'sales'), (108, '5'), (109, 'plans'), (110, 'six'), (111, 'old'), (112, 'half'), (113, 'already'), (114, 'put'), (115, 'brown'), (116, 'growth'), (117, 'months'), (118, 'come'), (119, 'day'), (120, 'm'), (121, 'london'), (122, 'chief'), (123, 'service'), (124, 'net'), (125, 'britain'), (126, 'economy'), (127, 'former'), (128, 'don'), (129, 'long'), (130, '2005'), (131, 'money'), (132, 'director'), (133, 'tax'), (134, 'deal'), (135, 'companies'), (136, 'services'), (137, 'right'), (138, 'record'), (139, 'industry'), (140, 'according'), (141, 'help'), (142, 'based'), (143, 'need'), (144, 'month'), (145, 'system'), (146, 'users'), (147, 'digital'), (148, 'big'), (149, 'europe'), (150, 'including'), (151, 'international'), (152, 'place'), (153, 'team'), (154, 'third'), (155, 'around'), (156, 'firms'), (157, '2003'), (158, 'report'), (159, 'business'), (160, 'economic'), (161, 'wales'), (162, 're'), (163, 'called'), (164, 'great'), (165, 'really'), (166, 'phone'), (167, 'move'), (168, 'software'), (169, 'another'), (170, 'open'), (171, 'life'), (172, 'bank'), (173, 'final'), (174, '7'), (175, 'got'), (176, 'future'), (177, 'hit'), (178, 'start'), (179, 'club'), (180, 'took'), (181, 'general'), (182, 'up'), (183, 'howard'), (184, 'video'), (185, 'know'), (186, 'came'), (187, 'france'), (188, 'better'), (189, 'spokesman'), (190, 'information'), (191, 'radio'), (192, 'state'), (193, 'office'), (194, 'law'), (195, 'online'), (196, 'without'), (197, 'court'), (198, 'decision'), (199, 'side'), (200, 'real'), (201, 'united'), (202, 'ireland'), (203, 'computer'), (204, 'despite'), (205, 'president'), (206, 'found'), (207, 'far'), (208, 'making'), (209, 'campaign'), (210, 'action'), (211, 'using'), (212, 'likely'), (213, 'prime'), (214, 'data'), (215, 'security'), (216, 'seen'), (217, 'figures'), (218, 'china'), (219, 'give'), (220, 'media'), (221, 'saying'), (222, 'line'), (223, 've'), (224, 'lot'), (225, 'given'), (226, 'national'), (227, 'run'), (228, 'o'), (229, 'awards'), (230, 'away'), (231, 'executive'), (232, 'able'), (233, 'offer'), (234, 'countries'), (235, 'foreign'), (236, 'every'), (237, 'january'), (238, 'star'), (239, 'it'), (240, 'player'), (241, 'internet'), (242, 'oil'), (243, 'lost'), (244, 'times'), (245, 'become'), (246, 'december'), (247, 'rise'), (248, 'biggest'), (249, 'match'), (250, 'cup'), (251, 'although'), (252, 'left'), (253, 'look'), (254, 'anti'), (255, 'man'), (256, 'nations'), (257, 'playing'), (258, 'cost'), (259,  ...

# %%
e = model.layers[0]
weights = e.get_weights()[0]
print(weights.shape) # shape: (vocab_size, embedding_dim)

# Expected output
# (12000, 20)
# Out:
# (12000, 20)

# %%
import io

out_v = io.open('vecs.tsv', 'w', encoding='utf-8')
out_m = io.open('meta.tsv', 'w', encoding='utf-8')
for word_num in range(1, vocab_size):
  word = reverse_word_index[word_num]
  embeddings = weights[word_num]
  out_m.write(word + "\n")
  out_v.write('\t'.join([str(x) for x in embeddings]) + "\n")
out_v.close()
out_m.close()

# %%
try:
  from google.colab import files
except ImportError:
  pass
else:
  files.download('vecs.tsv')
  files.download('meta.tsv')
